# %% [markdown]
# <a href="https://colab.research.google.com/github/paula-ioni/paula-ioni.github.io/blob/main/weather%20api%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/hourly"

querystring = {"lat":"51.454514","lon":"-2.58791","lang":"en","hours":"120","units":"metric"}

headers = {
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com",
    'x-rapidapi-key': "0c79be3448mshcc52080607eaf69p1ee398jsnca8f9401fbaa"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"data":[{"wind_cdir":"ESE","rh":83,"pod":"d","timestamp_utc":"2021-12-16T12:00:00","pres":1031.6,"solar_rad":221.371,"ozone":296.8,"weather":{"icon":"c01d","code":800,"description":"Clear Sky"},"wind_gust_spd":1.17,"timestamp_local":"2021-12-16T12:00:00","snow_depth":0,"clouds":12,"ts":1639656000,"wind_spd":0.32,"pop":0,"wind_cdir_full":"east-southeast","slp":1038.3,"dni":614,"dewpt":4.2,"snow":0,"uv":1.6,"wind_dir":110,"clouds_hi":0,"precip":0,"vis":24.128,"dhi":68.98,"app_temp":7.3,"datetime":"2021-12-16:12","temp":10.3,"ghi":221.51,"clouds_mid":0,"clouds_low":12},{"wind_cdir":"E","rh":77,"pod":"d","timestamp_utc":"2021-12-16T13:00:00","pres":1032,"solar_rad":204.863,"ozone":294.3,"weather":{"icon":"c01d","code":800,"description":"Clear Sky"},"wind_gust_spd":1.42,"timestamp_local":"2021-12-16T13:00:00","snow_depth":0,"clouds":11,"ts":1639659600,"wind_spd":0.53,"pop":0,"wind_cdir_full":"east","slp":1038.7,"dni":595.48,"dewpt":4.5,"snow":0,"uv":1.6,"wind_dir":95,"clouds_hi":0,"preci
# ...
