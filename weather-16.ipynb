# %% [markdown]
# <a href="https://colab.research.google.com/github/paula-ioni/paula-ioni.github.io/blob/main/weather-16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/daily"

querystring = {"lat":"51.4545","lon":"-2.5879","units":"metric","lang":"en"}

headers = {
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com",
    'x-rapidapi-key': "0c79be3448mshcc52080607eaf69p1ee398jsnca8f9401fbaa"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"data":[{"moonrise_ts":1639664673,"wind_cdir":"ESE","rh":89,"pres":1032.3,"high_temp":10.2,"sunset_ts":1639670517,"ozone":293.5,"moon_phase":0.96812,"wind_gust_spd":1.3,"snow_depth":0,"clouds":42,"ts":1639638060,"sunrise_ts":1639642176,"app_min_temp":-2.3,"wind_spd":0.6,"pop":0,"wind_cdir_full":"east-southeast","slp":1039,"moon_phase_lunation":0.43,"valid_date":"2021-12-16","app_max_temp":10.7,"vis":24.128,"dewpt":3.3,"snow":0,"uv":0,"weather":{"icon":"c03d","code":803,"description":"Broken clouds"},"wind_dir":119,"max_dhi":null,"clouds_hi":0,"precip":0,"low_temp":1.1,"max_temp":10.7,"moonset_ts":1639636477,"datetime":"2021-12-16","temp":5.2,"min_temp":2.1,"clouds_mid":0,"clouds_low":42},{"moonrise_ts":1639752463,"wind_cdir":"ENE","rh":97,"pres":1033.3,"high_temp":7,"sunset_ts":1639756936,"ozone":301.5,"moon_phase":0.993282,"wind_gust_spd":4.2,"snow_depth":0,"clouds":92,"ts":1639699260,"sunrise_ts":1639728621,"app_min_temp":-3.6,"wind_spd":1.9,"pop":0,"wind_cdir_full":"east-northeas
# ...
